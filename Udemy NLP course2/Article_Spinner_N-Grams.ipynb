# %%
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
from collections import Counter

# %%
df = pd.read_csv("bbc_text_cls.csv")

# %%
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
df.labels.unique()
# Out:
# array(['business', 'entertainment', 'politics', 'sport', 'tech'],
#       dtype=object)

# %%
labels = 'business'

# %%
texts = df[df['labels']==labels]["text"]

# %%
probs = Counter() #key: (w(t-1), w(t+1)), value: {w(t): count(w(t))}
for doc in texts:
    lines = doc.split("\n")
    for line in lines:
        tokens = word_tokenize(line)
        for i in range(len(tokens)-2):
            t_0 = tokens[i]
            t_1 = tokens[i+1]
            t_2 = tokens[i+2]
            key = (t_0,t_2)
            if key not in probs:
                probs[key]=Counter()
                if t_1 not in probs:
                    probs[key][t_1] = 1
                else:
                    probs[key][t_1] += 1

# %%
for key,d in probs.items():
    total = sum(d.values())
    for k,v in d.items():
        d[k] = v/total

# %%
probs
# Out:
# Counter({('Ad', 'boost'): Counter({'sales': 1.0}),
#          ('sales', 'Time'): Counter({'boost': 1.0}),
#          ('boost', 'Warner'): Counter({'Time': 1.0}),
#          ('Time', 'profit'): Counter({'Warner': 1.0}),
#          ('Quarterly', 'at'): Counter({'profits': 1.0}),
#          ('profits', 'US'): Counter({'at': 1.0}),
#          ('at', 'media'): Counter({'US': 1.0}),
#          ('US', 'giant'): Counter({'media': 1.0}),
#          ('media', 'TimeWarner'): Counter({'giant': 1.0}),
#          ('giant', 'jumped'): Counter({'TimeWarner': 1.0}),
#          ('TimeWarner', '76'): Counter({'jumped': 1.0}),
#          ('jumped', '%'): Counter({'76': 1.0}),
#          ('76', 'to'): Counter({'%': 1.0}),
#          ('%', '$'): Counter({'to': 1.0}),
#          ('to', '1.13bn'): Counter({'$': 1.0}),
#          ('$', '('): Counter({'1.13bn': 1.0}),
#          ('1.13bn', '£600m'): Counter({'(': 1.0}),
#          ('(', ')'): Counter({'£600m': 1.0}),
#          ('£600m', 'for'): Counter({')': 1.0}),
#          (')', 'the'): Counter({'for': 1.0}),
#          ('for', 'three'): Counter({'the': 1.0}),
#          ('the', 'months'): Counter({'three': 1.0}),
#          ('three', 'to'): Counter({'months': 1.0}),
#          ('months', 'December'): Counter({'to': 1.0}),
#          ('to', ','): Counter({'December': 1.0}),
#          ('December', 'from'): Counter({',': 1.0}),
#          (',', '$'): Counter({'from': 1.0}),
#          ('from', '639m'): Counter({'$': 1.0}),
#          ('$', 'year-earlier'): Counter({'639m': 1.0}),
#          ('639m', '.'): Counter({'year-earlier': 1.0}),
#          ('The', ','): Counter({'firm': 1.0}),
#          ('firm', 'which'): Counter({',': 1.0}),
#          (',', 'is'): Counter({'which': 1.0}),
#          ('which', 'now'): Counter({'is': 1.0}),
#          ('is', 'one'): Counter({'now': 1.0}),
#          ('now', 'of'): Counter({'one': 1.0}),
#          ('one', 'the'): Counter({'of': 1.0}),
#          ('of', 'biggest'): Counter({'the': 1.0}),
#          ('the', 'investors'): Counter({'biggest': 1.0}),
#          ('biggest', 'in'): Counter({'investors': 1.0}),
#          ('investors', 'Google'): Counter({'in': 1.0}),
#          ('in', ','): Counter({'Google': 1.0}),
#          ('Google', 'benefited'): Counter({',': 1.0}),
#          (',', 'from'): Counter({'benefited': 1.0}),
#          ('benefited', 'sales'): Counter({'from': 1.0}),
#          ('from', 'of'): Counter({'sales': 1.0}),
#          ('sales', 'high-speed'): Counter({'of': 1.0}),
#          ('of', 'internet'): Counter({'high-speed': 1.0}),
#          ('high-speed', 'connections'): Counter({'internet': 1.0}),
#          ('internet', 'and'): Counter({'connections': 1.0}),
#          ('connections', 'higher'): Counter({'and': 1.0}),
#          ('and', 'advert'): Counter({'higher': 1.0}),
#          ('higher', 'sales'): Counter({'advert': 1.0}),
#          ('advert', '.'): Counter({'sales': 1.0}),
#          ('sales', 'TimeWarner'): Counter({'.': 1.0}),
#          ('.', 'said'): Counter({'TimeWarner': 1.0}),
#          ('TimeWarner', 'fourth'): Counter({'said': 1.0}),
#          ('said', 'quarter'): Counter({'fourth': 1.0}),
#          ('fourth', 'sales'): Counter({'quarter': 1.0}),
#          ('quarter', 'rose'): Counter({'sales': 1.0}),
#          ('sales', '2'): Counter({'rose': 1.0}),
#          ('rose', '%'): Counter({'2': 1.0}),
#          ('2', 'to'): Counter({'%': 1.0}),
#          ('to', '11.1bn'): Counter({'$': 1.0}),
#          ('$', 'from'): Counter({'11.1bn': 1.0}),
#          ('11.1bn', '$'): Counter({'from': 1.0}),
#          ('from', '10.9bn'): Counter({'$': 1.0}),
#          ('$', '.'): Counter({'10.9bn': 1.0}),
#          ('10.9bn', 'Its'): Counter({'.': 1.0}),
#          ('.', 'profits'): Counter({'Its': 1.0}),
#          ('Its', 'were'): Counter({'profits': 1.0}),
#          ('profits', 'buoyed'): Counter({'were': 1.0}),
#          ('were', 'by'): Counter({'buoyed': 1.0}),
#          ('buoyed', 'one-off'): Counter({'by': 1.0}),
#          ('by', 'gains'): Counter({'one-off': 1.0}),
#          ('one-off', 'which'): Counter({'gains': 1.0}),
#          ('gains', 'offset'): Counter({'which': 1.0}),
#          ('which', 'a'): Counter({'offset': 1.0}),
#          ('offset', 'profit'): Counter({'a': 1.0}),
#          ('a', 'dip'): Counter({'profit': 1.0}),
#          ('profit', 'at'): Counter({'dip': 1.0}),
#          ('dip', 'Warner'): Counter({'at': 1.0}),
#          ('at', 'Bros'): Counter({'Warner': 1.0}),
#          ('Warner', ','): Counter({'Bros': 1.0}),
#          ('Bros', 'and'): Counter({',': 1.0}),
#          (',', 'less'): Counter({'and': 1.0}),
#          ('and', 'users'): Counter({'less': 1.0}),
#          ('less', 'for'): Counter({'users': 1.0}),
#          ('users', 'AOL'): Counter({'for': 1.0}),
#          ('for', '.'): Counter({'AOL': 1.0}),
#          ('Time', 'said'): Counter({'Warner': 1.0}),
#          ('Warner', 'on'): Counter({'said': 1.0}),
#          ('said', 'Friday'): Counter({'on': 1.0}),
#          ('on', 'that'): Counter({'Friday': 1.0}),
#          ('Friday', 'it'): Counter({'that': 1.0}),
#          ('that', 'now'): Counter({'it': 1.0}),
#          ('it', 'owns'): Counter({'now': 1.0}),
#          ('now', '8'): Counter({'owns': 1.0}),
#          ('owns', '%'): Counter({'8': 1.0}),
#          ('8', 'of'): Counter({'%': 1.0}),
#          ('%', 'search-engine'): Counter({'of': 1.0}),
#          ('of', 'Google'): Counter({'search-engine': 1.0}),
#          ('search-engine', '.'): Counter({'Google': 1.0}),
#          ('Google', 'But'): Counter({'.': 1.0}),
#          ('.', 'its'): Counter({'But': 1.0}),
#          ('But', 'own'): Counter({'its': 1.0}),
#          ('its', 'internet'): Counter({'own': 1.0}),
#          ('own', 'business'): Counter({'internet': 1.0}),
#          ('internet', ','): Counter({'business': 1.0}),
#          ('business', 'AOL'): Counter({',': 1.0}),
#          (',', ','): Counter({'AOL': 1.0}),
#          ('AOL', 'had'): Counter({',': 1.0}),
#          (',', 'has'): Counter({'had': 1.0}),
#          ('had', 'mixed'): Counter({'has': 1.0}),
#          ('has', 'fortunes'): Counter({'mixed': 1.0}),
#          ('mixed', '.'): Counter({'fortunes': 1.0}),
#          ('fortunes', 'It'): Counter({'.': 1.0}),
#          ('.', 'lost'): Counter({'It': 1.0}),
#          ('It', '464,000'): Counter({'lost': 1.0}),
#          ('lost', 'subscribers'): Counter({'464,000': 1.0}),
#          ('464,000', 'in'): Counter({'subscribers': 1.0}),
#          ('subscribers', 'the'): Counter({'in': 1.0}),
#          ('in', 'fourth'): Counter({'the': 1.0}),
#          ('the', 'quarter'): Counter({'fourth': 1.0}),
#          ('fourth', 'profits'): Counter({'quarter': 1.0}),
#          ('quarter', 'were'): Counter({'profits': 1.0}),
#          ('profits', 'lower'): Counter({'were': 1.0}),
#          ('were', 'than'): Counter({'lower': 1.0}),
#          ('lower', 'in'): Counter({'than': 1.0}),
#          ('than', 'the'): Counter({'in': 1.0}),
#          ('in', 'preceding'): Counter({'the': 1.0}),
#          ('the', 'three'): Counter({'preceding': 1.0}),
#          ('preceding', 'quarters'): Counter({'three': 1.0}),
#          ('three', '.'): Counter({'quarters': 1.0}),
#          ('quarters', 'However'): Counter({'.': 1.0}),
#          ('.', ','): Counter({'However': 1.0}),
#          ('However', 'the'): Counter({',': 1.0}),
#          (',', 'company'): Counter({'the': 1.0}),
#          ('the', 'said'): Counter({'company': 1.0}),
#          ('company', 'AOL'): Counter({'said': 1.0}),
#          ('said', "'s"): Counter({'AOL': 1.0}),
#          ('AOL', 'underlying'): Counter({"'s": 1.0}),
#          ("'s", 'profit'): Counter({'underlying': 1.0}),
#          ('underlying', 'before'): Counter({'profit': 1.0}),
#          ('profit', 'exceptional'): Counter({'before': 1.0}),
#          ('before', 'items'): Counter({'exceptional': 1.0}),
#          ('exceptional', 'rose'): Counter({'items': 1.0}),
#          ('items', '8'): Counter({'rose': 1.0}),
#          ('8', 'on'): Counter({'%': 1.0}),
#          ('%', 'the'): Counter({'on': 1.0}),
#          ('on', 'back'): Counter({'the': 1.0}),
#          ('the', 'of'): Counter({'back': 1.0}),
#          ('back', 'stronger'): Counter({'of': 1.0}),
#          ('stronger', 'advertising'): Counter({'internet': 1.0}),
#          ('internet', 'revenues'): Counter({'advertising': 1.0}),
#          ('advertising', '.'): Counter({'revenues': 1.0}),
#          ('revenues', 'It'): Counter({'.': 1.0}),
#          ('.', 'hopes'): Counter({'It': 1.0}),
#          ('It', 'to'): Counter({'hopes': 1.0}),
#          ('hopes', 'increase'): Counter({'to': 1.0}),
#          ('to', 'subscribers'): Counter({'increase': 1.0}),
#          ('increase', 'by'): Counter({'subscribers': 1.0}),
#          ('subscribers', 'offering'): Counter({'by': 1.0}),
#          ('by', 'the'): Counter({'offering': 1.0}),
#          ('offering', 'online'): Counter({'the': 1.0}),
#          ('the', 'service'): Counter({'online': 1.0}),
#          ('online', 'free'): Counter({'service': 1.0}),
#          ('service', 'to'): Counter({'free': 1.0}),
#          ('free', 'TimeWarner'): Counter({'to': 1.0}),
#          ('to', 'internet'): Counter({'TimeWarner': 1.0}),
#          ('TimeWarner', 'customers'): Counter({'internet': 1.0}),
#          ('customers', 'will'): Counter({'and': 1.0}),
#          ('and', 'try'): Counter({'will': 1.0}),
#          ('will', 'to'): Counter({'try': 1.0}),
#          ('try', 'sign'): Counter({'to': 1.0}),
#          ('to', 'up'): Counter({'sign': 1.0}),
#          ('sign', 'AOL'): Counter({'up': 1.0}),
#          ('up', "'s"): Counter({'AOL': 1.0}),
#          ('AOL', 'existing'): Counter({"'s": 1.0}),
#          ("'s", 'customers'): Counter({'existing': 1.0}),
#          ('existing', 'for'): Counter({'customers': 1.0}),
#          ('customers', 'high-speed'): Counter({'for': 1.0}),
#          ('for', 'broadband'): Counter({'high-speed': 1.0}),
#          ('high-speed', '.'): Counter({'broadband': 1.0}),
#          ('broadband', 'TimeWarner'): Counter({'.': 1.0}),
#          ('.', 'also'): Counter({'TimeWarner': 1.0}),
#          ('TimeWarner', 'has'): Counter({'also': 1.0}),
#          ('also', 'to'): Counter({'has': 1.0}),
#          ('has', 'restate'): Counter({'to': 1.0}),
#          ('to', '2000'): Counter({'restate': 1.0}),
#          ('restate', 'and'): Counter({'2000': 1.0}),
#          ('2000', '2003'): Counter({'and': 1.0}),
#          ('and', 'results'): Counter({'2003': 1.0}),
#          ('2003', 'following'): Counter({'results': 1.0}),
#          ('results', 'a'): Counter({'following': 1.0}),
#          ('following', 'probe'): Counter({'a': 1.0}),
#          ('a', 'by'): Counter({'probe': 1.0}),
#          ('probe', 'the'): Counter({'by': 1.0}),
#          ('by', 'US'): Counter({'the': 1.0}),
#          ('the', 'Securities'): Counter({'US': 1.0}),
#          ('US', 'Exchange'): Counter({'Securities': 1.0}),
#          ('Securities', 'Commission'): Counter({'Exchange': 1.0}),
#          ('Exchange', '('): Counter({'Commission': 1.0}),
#          ('Commission', 'SEC'): Counter({'(': 1.0}),
#          ('SEC', ','): Counter({')': 1.0}),
#          (')', 'which'): Counter({',': 1.0}),
#          ('which', 'close'): Counter({'is': 1.0}),
#          ('is', 'to'): Counter({'close': 1.0}),
#          ('close', 'concluding'): Counter({'to': 1.0}),
#          ('to', '.'): Counter({'concluding': 1.0}),
#          ('Time', "'s"): Counter({'Warner': 1.0}),
#          ('Warner', 'fourth'): Counter({"'s": 1.0}),
#          ("'s", 'quarter'): Counter({'fourth': 1.0}),
#          ('profits', 'slightly'): Counter({'were': 1.0}),
#          ('were', 'better'): Counter({'slightly': 1.0}),
#          ('slightly', 'than'): Counter({'better': 1.0}),
#          ('better', 'analysts'): Counter({'than': 1.0}),
#          ('than', "'"): Counter({'analysts': 1.0}),
#          ('analysts', 'expectations'): Counter({"'": 1.0}),
#          ("'", '.'): Counter({'expectations': 1.0}),
#          ('expectations', 'But'): Counter({'.': 1.0}),
#          ('But', 'film'): Counter({'its': 1.0}),
#          ('its', 'division'): Counter({'film': 1.0}),
#          ('film', 'saw'): Counter({'division': 1.0}),
#          ('division', 'profits'): Counter({'saw': 1.0}),
#          ('saw', 'slump'): Counter({'profits': 1.0}),
#          ('profits', '27'): Counter({'slump': 1.0}),
#          ('slump', '%'): Counter({'27': 1.0}),
#          ('27', 'to'): Counter({'%': 1.0}),
#          ('to', '284m'): Counter({'$': 1.0}),
#          ('$', ','): Counter({'284m': 1.0}),
#          ('284m', 'helped'): Counter({',': 1.0}),
#          (',', 'by'): Counter({'helped': 1.0}),
#          ('helped', 'box-office'): Counter({'by': 1.0}),
#          ('by', 'flops'): Counter({'box-office': 1.0}),
#          ('box-office', 'Alexander'): Counter({'flops': 1.0}),
#          ('flops', 'and'): Counter({'Alexander': 1.0}),
#          ('Alexander', 'Catwoman'): Counter({'and': 1.0}),
#          ('and', ','): Counter({'Catwoman': 1.0}),
#          ('Catwoman', 'a'): Counter({',': 1.0}),
#          (',', 'sharp'): Counter({'a': 1.0}),
#          ('a', 'contrast'): Counter({'sharp': 1.0}),
#          ('sharp', 'to'): Counter({'contrast': 1.0}),
#          ('contrast', 'year-earlier'): Counter({'to': 1.0}),
#          ('year-earlier', 'when'): Counter({',': 1.0}),
#          (',', 'the'): Counter({'when': 1.0}),
#          ('when', 'third'): Counter({'the': 1.0}),
#          ('the', 'and'): Counter({'third': 1.0}),
#          ('third', 'final'): Counter({'and': 1.0}),
#          ('and', 'film'): Counter({'final': 1.0}),
#          ('final', 'in'): Counter({'film': 1.0}),
#          ('film', 'the'): Counter({'in': 1.0}),
#          ('in', 'Lord'): Counter({'the': 1.0}),
#          ('Lord', 'the'): Counter({'of': 1.0}),
#          ('of', 'Rings'): Counter({'the': 1.0}),
#          ('the', 'trilogy'): Counter({'Rings': 1.0}),
#          ('Rings', 'boosted'): Counter({'trilogy': 1.0}),
#          ('trilogy', 'results'): Counter({'boosted': 1.0}),
#          ('boosted', '.'): Counter({'results': 1.0}),
#          ('results', 'For'): Counter({'.': 1.0}),
#          ('.', 'the'): Counter({'For': 1.0}),
#          ('For', 'full-year'): Counter({'the': 1.0}),
#          ('the', ','): Counter({'full-year': 1.0}),
#          ('full-year', 'TimeWarner'): Counter({',': 1.0}),
#          (',', 'posted'): Counter({'TimeWarner': 1.0}),
#          ('TimeWarner', 'a'): Counter({'posted': 1.0}),
#          ('posted', 'profit'): Counter({'a': 1.0}),
#          ('a', 'of'): Counter({'profit': 1.0}),
#          ('profit', '$'): Counter({'of': 1.0}),
#          ('of', '3.36bn'): Counter({'$': 1.0}),
#          ('3.36bn', 'up'): Counter({',': 1.0}),
#          (',', '27'): Counter({'up': 1.0}),
#          ('up', '%'): Counter({'27': 1.0}),
#          ('27', 'from'): Counter({'%': 1.0}),
#          ('%', 'its'): Counter({'from': 1.0}),
#          ('from', '2003'): Counter({'its': 1.0}),
#          ('its', 'performance'): Counter({'2003': 1.0}),
#          ('2003', ','): Counter({'performance': 1.0}),
#          ('performance', 'while'): Counter({',': 1.0}),
#          (',', 'revenues'): Counter({'while': 1.0}),
#          ('while', 'grew'): Counter({'revenues': 1.0}),
#          ('revenues', '6.4'): Counter({'grew': 1.0}),
#          ('grew', '%'): Counter({'6.4': 1.0}),
#          ('6.4', 'to'): Counter({'%': 1.0}),
#          ('to', '42.09bn'): Counter({'$': 1.0}),
#          ('42.09bn', '``'): Counter({'.': 1.0}),
#          ('.', 'Our'): Counter({'``': 1.0}),
#          ('``', 'financial'): Counter({'Our': 1.0}),
#          ('Our', 'performance'): Counter({'financial': 1.0}),
#          ('financial', 'was'): Counter({'performance': 1.0}),
#          ('performance', 'strong'): Counter({'was': 1.0}),
#          ('was', ','): Counter({'strong': 1.0}),
#          ('strong', 'meeting'): Counter({',': 1.0}),
#          (',', 'or'): Counter({'meeting': 1.0}),
#          ('meeting', 'exceeding'): Counter({'or': 1.0}),
#          ('or', 'all'): Counter({'exceeding': 1.0}),
#          ('exceeding', 'of'): Counter({'all': 1.0}),
#          ('all', 'our'): Counter({'of': 1.0}),
#          ('of', 'full-year'): Counter({'our': 1.0}),
#          ('our', 'objectives'): Counter({'full-year': 1.0}),
#          ('full-year', 'and'): Counter({'objectives': 1.0}),
#          ('objectives', 'greatly'): Counter({'and': 1.0}),
#          ('and', 'enhancing'): Counter({'greatly': 1.0}),
#          ('greatly', 'our'): Counter({'enhancing': 1.0}),
#          ('enhancing', 'flexibility'): Counter({'our': 1.0}),
#          ('our', ','): Counter({'flexibility': 1.0}),
#          ('flexibility', "''"): Counter({',': 1.0}),
#          (',', 'chairman'): Counter({"''": 1.0}),
#          ("''", 'and'): Counter({'chairman': 1.0}),
#          ('chairman', 'chief'): Counter({'and': 1.0}),
#          ('and', 'executive'): Counter({'chief': 1.0}),
#          ('chief', 'Richard'): Counter({'executive': 1.0}),
#          ('executive', 'Parsons'): Counter({'Richard': 1.0}),
#          ('Richard', 'said'): Counter({'Parsons': 1.0}),
#          ('Parsons', '.'): Counter({'said': 1.0}),
#          ('said', 'For'): Counter({'.': 1.0}),
#          ('.', '2005'): Counter({'For': 1.0}),
#          ('For', ','): Counter({'2005': 1.0}),
#          ('2005', 'TimeWarner'): Counter({',': 1.0}),
#          ('TimeWarner', 'projecting'): Counter({'is': 1.0}),
#          ('is', 'operating'): Counter({'projecting': 1.0}),
#          ('projecting', 'earnings'): Counter({'operating': 1.0}),
#          ('operating', 'growth'): Counter({'earnings': 1.0}),
#          ('earnings', 'of'): Counter({'growth': 1.0}),
#          ('growth', 'around'): Counter({'of': 1.0}),
#          ('of', '5'): Counter({'around': 1.0}),
#          ('around', '%'): Counter({'5': 1.0}),
#          ('5', ','): Counter({'%': 1.0}),
#          ('%', 'and'): Counter({',': 1.0}),
#          (',', 'also'): Counter({'and': 1.0}),
#          ('and', 'expects'): Counter({'also': 1.0}),
#          ('also', 'higher'): Counter({'expects': 1.0}),
#          ('expects', 'revenue'): Counter({'higher': 1.0}),
#          ('higher', 'and'): Counter({'revenue': 1.0}),
#          ('revenue', 'wider'): Counter({'and': 1.0}),
#          ('and', 'profit'): Counter({'wider': 1.0}),
#          ('wider', 'margins'): Counter({'profit': 1.0}),
#          ('profit', '.'): Counter({'margins': 1.0}),
#          ('TimeWarner', 'to'): Counter({'is': 1.0}),
#          ('is', 'restate'): Counter({'to': 1.0}),
#          ('to', 'its'): Counter({'restate': 1.0}),
#          ('restate', 'accounts'): Counter({'its': 1.0}),
#          ('its', 'as'): Counter({'accounts': 1.0}),
#          ('accounts', 'part'): Counter({'as': 1.0}),
#          ('as', 'of'): Counter({'part': 1.0}),
#          ('part', 'efforts'): Counter({'of': 1.0}),
#          ('of', 'to'): Counter({'efforts': 1.0}),
#          ('efforts', 'resolve'): Counter({'to': 1.0}),
#          ('to', 'an'): Counter({'resolve': 1.0}),
#          ('resolve', 'inquiry'): Counter({'an': 1.0}),
#          ('an', 'into'): Counter({'inquiry': 1.0}),
#          ('inquiry', 'AOL'): Counter({'into': 1.0}),
#          ('into', 'by'): Counter({'AOL': 1.0}),
#          ('AOL', 'US'): Counter({'by': 1.0}),
#          ('by', 'market'): Counter({'US': 1.0}),
#          ('US', 'regulators'): Counter({'market': 1.0}),
#          ('market', '.'): Counter({'regulators': 1.0}),
#          ('regulators', 'It'): Counter({'.': 1.0}),
#          ('.', 'has'): Counter({'It': 1.0}),
#          ('It', 'already'): Counter({'has': 1.0}),
#          ('has', 'offered'): Counter({'already': 1.0}),
#          ('already', 'to'): Counter({'offered': 1.0}),
#          ('offered', 'pay'): Counter({'to': 1.0}),
#          ('to', '$'): Counter({'pay': 1.0}),
#          ('pay', '300m'): Counter({'$': 1.0}),
#          ('$', 'to'): Counter({'300m': 1.0}),
#          ('300m', 'settle'): Counter({'to': 1.0}),
#          ('to', 'charges'): Counter({'settle': 1.0}),
#          ('settle', ','): Counter({'charges': 1.0}),
#          ('charges', 'in'): Counter({',': 1.0}),
#          (',', 'a'): Counter({'in': 1.0}),
#          ('in', 'deal'): Counter({'a': 1.0}),
#          ('a', 'that'): Counter({'deal': 1.0}),
#          ('deal', 'is'): Counter({'that': 1.0}),
#          ('that', 'under'): Counter({'is': 1.0}),
#          ('is', 'review'): Counter({'under': 1.0}),
#          ('under', 'by'): Counter({'review': 1.0}),
#          ('review', 'the'): Counter({'by': 1.0}),
#          ('by', 'SEC'): Counter({'the': 1.0}),
#          ('the', '.'): Counter({'SEC': 1.0}),
#          ('SEC', 'The'): Counter({'.': 1.0}),
#          ('.', 'company'): Counter({'The': 1.0}),
#          ('The', 'said'): Counter({'company': 1.0}),
#          ('company', 'it'): Counter({'said': 1.0}),
#          ('said', 'was'): Counter({'it': 1.0}),
#          ('it', 'unable'): Counter({'was': 1.0}),
#          ('was', 'to'): Counter({'unable': 1.0}),
#          ('unable', 'estimate'): Counter({'to': 1.0}),
#          ('to', 'the'): Counter({'estimate': 1.0}),
#          ('estimate', 'amount'): Counter({'the': 1.0}),
#          ('the', 'it'): Counter({'amount': 1.0}),
#          ('amount', 'needed'): Counter({'it': 1.0}),
#          ('it', 'to'): Counter({'needed': 1.0}),
#          ('needed', 'set'): Counter({'to': 1.0}),
#          ('to', 'aside'): Counter({'set': 1.0}),
#          ('set', 'for'): Counter({'aside': 1.0}),
#          ('aside', 'legal'): Counter({'for': 1.0}),
#          ('for', 'reserves'): Counter({'legal': 1.0}),
#          ('legal', ','): Counter({'reserves': 1.0}),
#          ('reserves', 'which'): Counter({',': 1.0}),
#          (',', 'it'): Counter({'which': 1.0}),
#          ('which', 'previously'): Counter({'it': 1.0}),
#          ('it', 'set'): Counter({'previously': 1.0}),
#          ('previously', 'at'): Counter({'set': 1.0}),
#          ('set', '$'): Counter({'at': 1.0}),
#          ('at', '500m'): Counter({'$': 1.0}),
#          ('500m', 'It'): Counter({'.': 1.0}),
#          ('.', 'intends'): Counter({'It': 1.0}),
#          ('intends', 'adjust'): Counter({'to': 1.0}),
#          ('adjust', 'way'): Counter({'the': 1.0}),
#          ('way', 'accounts'): Counter({'it': 1.0}),
#          ('it', 'for'): Counter({'accounts': 1.0}),
#          ('accounts', 'a'): Counter({'for': 1.0}),
#          ('for', 'deal'): Counter({'a': 1.0}),
#          ('a', 'with'): Counter({'deal': 1.0}),
#          ('deal', 'German'): Counter({'with': 1.0}),
#          ('with', 'music'): Counter({'German': 1.0}),
#          ('German', 'publisher'): Counter({'music': 1.0}),
#          ('music', 'Bertelsmann'): Counter({'publisher': 1.0}),
#          ('publisher', "'s"): Counter({'Bertelsmann': 1.0}),
#          ('Bertelsmann', 'purchase'): Counter({"'s": 1.0}),
#          ("'s", 'of'): Counter({'purchase': 1.0}),
#          ('purchase', 'a'): Counter({'of': 1.0}),
#          ('of', 'stake'): Counter({'a': 1.0}),
#          ('a', 'in'): Counter({'stake': 1.0}),
#          ('stake', 'AOL'): Counter({'in': 1.0}),
#          ('in', 'Europe'): Counter({'AOL': 1.0}),
#          ('AOL', ','): Counter({'Europe': 1.0}),
#          ('Europe', 'which'): Counter({',': 1.0}),
#          ('which', 'had'): Counter({'it': 1.0}),
#          ('it', 'reported'): Counter({'had': 1.0}),
#          ('had', 'as'): Counter({'reported': 1.0}),
#          ('reported', 'advertising'): Counter({'as': 1.0}),
#          ('as', 'revenue'): Counter({'advertising': 1.0}),
#          ('revenue', 'It'): Counter({'.': 1.0}),
#          ('.', 'will'): Counter({'It': 1.0}),
#          ('It', 'now'): Counter({'will': 1.0}),
#          ('will', 'book'): Counter({'now': 1.0}),
#          ('now', 'the'): Counter({'book': 1.0}),
#          ('book', 'sale'): Counter({'the': 1.0}),
#          ('sale', 'its'): Counter({'of': 1.0}),
#          ('its', 'in'): Counter({'stake': 1.0}),
#          ('AOL', 'as'): Counter({'Europe': 1.0}),
#          ('Europe', 'a'): Counter({'as': 1.0}),
#          ('as', 'loss'): Counter({'a': 1.0}),
#          ('a', 'on'): Counter({'loss': 1.0}),
#          ('loss', 'the'): Counter({'on': 1.0}),
#          ('on', 'value'): Counter({'the': 1.0}),
#          ('value', 'that'): Counter({'of': 1.0}),
#          ('that', '.'): Counter({'stake': 1.0}),
#          ('Dollar', 'on'): Counter({'gains': 1.0}),
#          ('gains', 'Greenspan'): Counter({'on': 1.0}),
#          ('on', 'speech'): Counter({'Greenspan': 1.0}),
#          ('The', 'has'): Counter({'dollar': 1.0}),
#          ('dollar', 'hit'): Counter({'has': 1.0}),
#          ('has', 'its'): Counter({'hit': 1.0}),
#          ('hit', 'highest'): Counter({'its': 1.0}),
#          ('its', 'level'): Counter({'highest': 1.0}),
#          ('highest', 'against'): Counter({'level': 1.0}),
#          ('level', 'the'): Counter({'against': 1.0}),
#          ('against', 'euro'): Counter({'the': 1.0}),
#          ('the', 'in'): Counter({'euro': 1.0}),
#          ('euro', 'almost'): Counter({'in': 1.0}),
#          ('in', 'three'): Counter({'almost': 1.0}),
#          ('almost', 'months'): Counter({'three': 1.0}),
#          ('three', 'after'): Counter({'months': 1.0}),
#          ('months', 'the'): Counter({'after': 1.0}),
#          ('after', 'Federal'): Counter({'the': 1.0}),
#          ('the', 'Reserve'): Counter({'Federal': 1.0}),
#          ('Federal', 'head'): Counter({'Reserve': 1.0}),
#          ('Reserve', 'said'): Counter({'head': 1.0}),
#          ('head', 'the'): Counter({'said': 1.0}),
#          ('said', 'US'): Counter({'the': 1.0}),
#          ('the', 'trade'): Counter({'US': 1.0}),
#          ('US', 'deficit'): Counter({'trade': 1.0}),
#          ('trade', 'is'): Counter({'deficit': 1.0}),
#          ('deficit', 'set'): Counter({'is': 1.0}),
#          ('set', 'stabilise'): Counter({'to': 1.0}),
#          ('And', 'Greenspan'): Counter({'Alan': 1.0}),
#          ('Alan', 'highlighted'): Counter({'Greenspan': 1.0}),
#          ('Greenspan', 'the'): Counter({'highlighted': 1.0}),
#          ('highlighted', 'US'): Counter({'the': 1.0}),
#          ('the', 'government'): Counter({'US': 1.0}),
#          ('US', "'s"): Counter({'government': 1.0}),
#          ('government', 'willingness'): Counter({"'s": 1.0}),
#          ("'s", 'to'): Counter({'willingness': 1.0}),
#          ('willingness', 'curb'): Counter({'to': 1.0}),
#          ('to', 'spending'): Counter({'curb': 1.0}),
#          ('curb', 'and'): Counter({'spending': 1.0}),
#          ('spending', 'rising'): Counter({'and': 1.0}),
#          ('and', 'household'): Counter({'rising': 1.0}),
#          ('rising', 'savings'): Counter({'household': 1.0}),
#          ('household', 'as'): Counter({'savings': 1.0}),
#          ('savings', 'factors'): Counter({'as': 1.0}),
#          ('as', 'which'): Counter({'factors': 1.0}),
#          ('factors', 'may'): Counter({'which': 1.0}),
#          ('which', 'help'): Counter({'may': 1.0}),
#          ('may', 'to'): Counter({'help': 1.0}),
#          ('help', 'reduce'): Counter({'to': 1.0}),
#          ('to', 'it'): Counter({'reduce': 1.0}),
#          ('reduce', '.'): Counter({'it': 1.0}),
#          ('it', 'In'): Counter({'.': 1.0}),
#          ('.', 'late'): Counter({'In': 1.0}),
#          ('In', 'trading'): Counter({'late': 1.0}),
#          ('late', 'in'): Counter({'trading': 1.0}),
#          ('trading', 'New'): Counter({'in': 1.0}),
#          ('in', 'York'): Counter({'New': 1.0}),
#          ('New', ','): Counter({'York': 1.0}),
#          ('York', 'the'): Counter({',': 1.0}),
#          (',', 'dollar'): Counter({'the': 1.0}),
#          ('the', 'reached'): Counter({'dollar': 1.0}),
#          ('dollar', '$'): Counter({'reached': 1.0}),
#          ('reached', '1.2871'): Counter({'$': 1.0}),
#          ('$', 'against'): Counter({'1.2871': 1.0}),
#          ('1.2871', 'the'): Counter({'against': 1.0}),
#          ('euro', 'from'): Counter({',': 1.0}),
#          ('from', '1.2974'): Counter({'$': 1.0}),
#          ('$', 'on'): Counter({'1.2974': 1.0}),
#          ('1.2974', 'Thursday'): Counter({'on': 1.0}),
#          ('on', '.'): Counter({'Thursday': 1.0}),
#          ('Thursday', 'Market'): Counter({'.': 1.0}),
#          ('.', 'concerns'): Counter({'Market': 1.0}),
#          ('Market', 'about'): Counter({'concerns': 1.0}),
#          ('concerns', 'the'): Counter({'about': 1.0}),
#          ('about', 'deficit'): Counter({'the': 1.0}),
#          ('the', 'has'): Counter({'deficit': 1.0}),
#          ('deficit', 'hit'): Counter({'has': 1.0}),
#          ('has', 'the'): Counter({'hit': 1.0}),
#          ('hit', 'greenback'): Counter({'the': 1.0}),
#          ('greenback', 'recent'): Counter({'in': 1.0}),
#          ('in', 'months'): Counter({'recent': 1.0}),
#          ('recent', '.'): Counter({'months': 1.0}),
#          ('months', 'On'): Counter({'.': 1.0}),
#          ('.', 'Friday'): Counter({'On': 1.0}),
#          ('On', ','): Counter({'Friday': 1.0}),
#          ('Friday', 'Federal'): Counter({',': 1.0}),
#          (',', 'Reserve'): Counter({'Federal': 1.0}),
#          ('Federal', 'chairman'): Counter({'Reserve': 1.0}),
#          ('Reserve', 'Mr'): Counter({'chairman': 1.0}),
#          ('chairman', 'Greenspan'): Counter({'Mr': 1.0}),
#          ('Mr', "'s"): Counter({'Greenspan': 1.0}),
#          ('Greenspan', 'speech'): Counter({"'s": 1.0}),
#          ("'s", 'in'): Counter({'speech': 1.0}),
#          ('speech', 'London'): Counter({'in': 1.0}),
#          ('in', 'ahead'): Counter({'London': 1.0}),
#          ('London', 'of'): Counter({'ahead': 1.0}),
#          ('ahead', 'the'): Counter({'of': 1.0}),
#          ('of', 'meeting'): Counter({'the': 1.0}),
#          ('meeting', 'G7'): Counter({'of': 1.0}),
#          ('of', 'finance'): Counter({'G7': 1.0}),
#          ('G7', 'ministers'): Counter({'finance': 1.0}),
#          ('finance', 'sent'): Counter({'ministers': 1.0}),
#          ('ministers', 'the'): Counter({'sent': 1.0}),
#          ('sent', 'dollar'): Counter({'the': 1.0}),
#          ('the', 'higher'): Counter({'dollar': 1.0}),
#          ('dollar', 'after'): Counter({'higher': 1.0}),
#          ('higher', 'it'): Counter({'after': 1.0}),
#          ('after', 'had'): Counter({'it': 1.0}),
#          ('it', 'earlier'): Counter({'had': 1.0}),
#          ('had', 'tumbled'): Counter({'earlier': 1.0}),
#          ('earlier', 'on'): Counter({'tumbled': 1.0}),
#          ('tumbled', 'the'): Counter({'on': 1.0}),
#          ('back', 'worse-than-expected'): Counter({'of': 1.0}),
#          ('of', 'US'): Counter({'worse-than-expected': 1.0}),
#          ('worse-than-expected', 'jobs'): Counter({'US': 1.0}),
#          ('US', 'data'): Counter({'jobs': 1.0}),
#          ('jobs', '.'): Counter({'data': 1.0}),
#          ('data', '``'): Counter({'.': 1.0}),
#          ('.', 'I'): Counter({'``': 1.0}),
#          ('``', 'think'): Counter({'I': 1.0}),
#          ('I', 'the'): Counter({'think': 1.0}),
#          ('think', 'chairman'): Counter({'the': 1.0}),
#          ('the', "'s"): Counter({'chairman': 1.0}),
#          ('chairman', 'taking'): Counter({"'s": 1.0}),
#          ("'s", 'a'): Counter({'taking': 1.0}),
#          ('taking', 'much'): Counter({'a': 1.0}),
#          ('a', 'more'): Counter({'much': 1.0}),
#          ('much', 'sanguine'): Counter({'more': 1.0}),
#          ('more', 'view'): Counter({'sanguine': 1.0}),
#          ('sanguine', 'on'): Counter({'view': 1.0}),
#          ('view', 'the'): Counter({'on': 1.0}),
#          ('on', 'current'): Counter({'the': 1.0}),
#          ('the', 'account'): Counter({'current': 1.0}),
#          ('current', 'deficit'): Counter({'account': 1.0}),
#          ('account', 'than'): Counter({'deficit': 1.0}),
#          ('deficit', 'he'): Counter({'than': 1.0}),
#          ('than', "'s"): Counter({'he': 1.0}),
#          ('he', 'taken'): Counter({"'s": 1.0}),
#          ("'s", 'for'): Counter({'taken': 1.0}),
#          ('taken', 'some'): Counter({'for': 1.0}),
#          ('for', 'time'): Counter({'some': 1.0}),
#          ('some', ','): Counter({'time': 1.0}),
#          ('time', "''"): Counter({',': 1.0}),
#          (',', 'said'): Counter({"''": 1.0}),
#          ("''", 'Robert'): Counter({'said': 1.0}),
#          ('said', 'Sinche'): Counter({'Robert': 1.0}),
#          ('Robert', ','): Counter({'Sinche': 1.0}),
#          ('Sinche', 'head'): Counter({',': 1.0}),
#          (',', 'of'): Counter({'head': 1.0}),
#          ('head', 'currency'): Counter({'of': 1.0}),
#          ('of', 'strategy'): Counter({'currency': 1.0}),
#          ('currency', 'at'): Counter({'strategy': 1.0}),
#          ('strategy', 'Bank'): Counter({'at': 1.0}),
#          ('at', 'of'): Counter({'Bank': 1.0}),
#          ('Bank', 'America'): Counter({'of': 1.0}),
#          ('of', 'in'): Counter({'America': 1.0}),
#          ('America', 'New'): Counter({'in': 1.0}),
#          ('New', '.'): Counter({'York': 1.0}),
#          ('York', '``'): Counter({'.': 1.0}),
#          ('.', 'He'): Counter({'``': 1.0}),
#          ('``', "'s"): Counter({'He': 1.0}),
#          ('He', 'taking'): Counter({"'s": 1.0}),
#          ('taking', 'longer-term'): Counter({'a': 1.0}),
#          ('a', 'view'): Counter({'longer-term': 1.0}),
#          ('longer-term', ','): Counter({'view': 1.0}),
#          ('view', 'laying'): Counter({',': 1.0}),
#          (',', 'out'): Counter({'laying': 1.0}),
#          ('laying', 'a'): Counter({'out': 1.0}),
#          ('out', 'set'): Counter({'a': 1.0}),
#          ('set', 'conditions'): Counter({'of': 1.0}),
#          ('of', 'under'): Counter({'conditions': 1.0}),
#          ('conditions', 'which'): Counter({'under': 1.0}),
#          ('under', 'the'): Counter({'which': 1.0}),
#          ('which', 'current'): Counter({'the': 1.0}),
#          ('account', 'can'): Counter({'deficit': 1.0}),
#          ('deficit', 'improve'): Counter({'can': 1.0}),
#          ('can', 'this'): Counter({'improve': 1.0}),
#          ('improve', 'year'): Counter({'this': 1.0}),
#          ('this', 'and'): Counter({'year': 1.0}),
#          ('year', 'next'): Counter({'and': 1.0}),
#          ('and', '.'): Counter({'next': 1.0}),
#          ('next', "''"): Counter({'.': 1.0}),
#          ('Worries', 'the'): Counter({'about': 1.0}),
#          ('the', 'concerns'): Counter({'deficit': 1.0}),
#          ('deficit', 'about'): Counter({'concerns': 1.0}),
#          ('concerns', 'China'): Counter({'about': 1.0}),
#          ('about', 'do'): Counter({'China': 1.0}),
#          ('China', ','): Counter({'do': 1.0}),
#          ('do', 'however'): Counter({',': 1.0}),
#          ('however', 'remain'): Counter({',': 1.0}),
#          (',', '.'): Counter({'remain': 1.0}),
#          ('remain', 'China'): Counter({'.': 1.0}),
#          ('.', "'s"): Counter({'China': 1.0}),
#          ('China', 'currency'): Counter({"'s": 1.0}),
#          ("'s", 'remains'): Counter({'currency': 1.0}),
#          ('currency', 'pegged'): Counter({'remains': 1.0}),
#          ('remains', 'to'): Counter({'pegged': 1.0}),
#          ('pegged', 'the'): Counter({'to': 1.0}),
#          ('to', 'dollar'): Counter({'the': 1.0}),
#          ('dollar', 'the'): Counter({'and': 1.0}),
#          ('and', 'US'): Counter({'the': 1.0}),
#          ('the', 'currency'): Counter({'US': 1.0}),
#          ('currency', 'sharp'): Counter({"'s": 1.0}),
#          ("'s", 'falls'): Counter({'sharp': 1.0}),
#          ('sharp', 'in'): Counter({'falls': 1.0}),
#          ('falls', 'recent'): Counter({'in': 1.0}),
#          ('recent', 'have'): Counter({'months': 1.0}),
#          ('months', 'therefore'): Counter({'have': 1.0}),
#          ('have', 'made'): Counter({'therefore': 1.0}),
#          ('therefore', 'Chinese'): Counter({'made': 1.0}),
#          ('made', 'export'): Counter({'Chinese': 1.0}),
#          ('Chinese', 'prices'): Counter({'export': 1.0}),
#          ('export', 'highly'): Counter({'prices': 1.0}),
#          ('prices', 'competitive'): Counter({'highly': 1.0}),
#          ('highly', '.'): Counter({'competitive': 1.0}),
#          ('competitive', 'But'): Counter({'.': 1.0}),
#          ('.', 'calls'): Counter({'But': 1.0}),
#          ('But', 'for'): Counter({'calls': 1.0}),
#          ('calls', 'a'): Counter({'for': 1.0}),
#          ('for', 'shift'): Counter({'a': 1.0}),
#          ('shift', 'Beijing'): Counter({'in': 1.0}),
#          ('in', "'s"): Counter({'Beijing': 1.0}),
#          ('Beijing', 'policy'): Counter({"'s": 1.0}),
#          ("'s", 'have'): Counter({'policy': 1.0}),
#          ('policy', 'fallen'): Counter({'have': 1.0}),
#          ('have', 'on'): Counter({'fallen': 1.0}),
#          ('fallen', 'deaf'): Counter({'on': 1.0}),
#          ('on', 'ears'): Counter({'deaf': 1.0}),
#          ('deaf', ','): Counter({'ears': 1.0}),
#          ('ears', 'despite'): Counter({',': 1.0}),
#          (',', 'recent'): Counter({'despite': 1.0}),
#          ('despite', 'comments'): Counter({'recent': 1.0}),
#          ('recent', 'in'): Counter({'comments': 1.0}),
#          ('comments', 'a'): Counter({'in': 1.0}),
#          ('in', 'major'): Counter({'a': 1.0}),
#          ('a', 'Chinese'): Counter({'major': 1.0}),
#          ('major', 'newspaper'): Counter({'Chinese': 1.0}),
#          ('Chinese', 'that'): Counter({'newspaper': 1.0}),
#          ('newspaper', 'the'): Counter({'that': 1.0}),
#          ('that', '``'): Counter({'the': 1.0}),
#          ('the', 'time'): Counter({'``': 1.0}),
#          ('``', 'is'): Counter({'time': 1.0}),
#          ('time', 'ripe'): Counter({'is': 1.0}),
#          ('is', "''"): Counter({'ripe': 1.0}),
#          ('ripe', 'for'): Counter({"''": 1.0}),
#          ("''", 'a'): Counter({'for': 1.0}),
#          ('for', 'loosening'): Counter({'a': 1.0}),
#          ('loosening', 'the'): Counter({'of': 1.0}),
#          ('of', 'peg'): Counter({'the': 1.0}),
#          ('peg', 'The'): Counter({'.': 1.0}),
#          ('.', 'G7'): Counter({'The': 1.0}),
#          ('The', 'meeting'): Counter({'G7': 1.0}),
#          ('G7', 'is'): Counter({'meeting': 1.0}),
#          ('meeting', 'thought'): Counter({'is': 1.0}),
#          ('is', 'unlikely'): Counter({'thought': 1.0}),
#          ('thought', 'to'): Counter({'unlikely': 1.0}),
#          ('unlikely', 'produce'): Counter({'to': 1.0}),
#          ('to', 'any'): Counter({'produce': 1.0}),
#          ('produce', 'meaningful'): Counter({'any': 1.0}),
#          ('any', 'movement'): Counter({'meaningful': 1.0}),
#          ('meaningful', 'in'): Counter({'movement': 1.0}),
#          ('movement', 'Chinese'): Counter({'in': 1.0}),
#          ('in', 'policy'): Counter({'Chinese': 1.0}),
#          ('Chinese', '.'): Counter({'policy': 1.0}),
#          ('policy', 'In'): Counter({'.': 1.0}),
#          ('In', 'meantime'): Counter({'the': 1.0}),
#          ('meantime', 'the'): Counter({',': 1.0}),
#          (',', 'US'): Counter({'the': 1.0}),
#          ('the', 'Federal'): Counter({'US': 1.0}),
#          ('US', 'Reserve'): Counter({'Federal': 1.0}),
#          ('Federal', "'s"): Counter({'Reserve': 1.0}),
#          ('Reserve', 'decision'): Counter({"'s": 1.0}),
#          ("'s", 'on'): Counter({'decision': 1.0}),
#          ('decision', '2'): Counter({'on': 1.0}),
#          ('on', 'February'): Counter({'2': 1.0}),
#          ('February', 'boost'): Counter({'to': 1.0}),
#          ('to', 'interest'): Counter({'boost': 1.0}),
#          ('boost', 'rates'): Counter({'interest': 1.0}),
#          ('interest', 'by'): Counter({'rates': 1.0}),
#          ('rates', 'a'): Counter({'by': 1.0}),
#          ('by', 'quarter'): Counter({'a': 1.0}),
#          ('quarter', 'a'): Counter({'of': 1.0}),
#          ('of', 'point'): Counter({'a': 1.0}),
#          ('a', '-'): Counter({'point': 1.0}),
#          ('point', 'the'): Counter({'-': 1.0}),
#          ('-', 'sixth'): Counter({'the': 1.0}),
#          ('the', 'such'): Counter({'sixth': 1.0}),
#          ('sixth', 'move'): Counter({'such': 1.0}),
#          ('such', 'in'): Counter({'move': 1.0}),
#          ('move', 'as'): Counter({'in': 1.0}),
#          ('in', 'many'): Counter({'as': 1.0}),
#          ('as', 'months'): Counter({'many': 1.0}),
#          ('many', '-'): Counter({'months': 1.0}),
#          ('months', 'has'): Counter({'-': 1.0}),
#          ('-', 'opened'): Counter({'has': 1.0}),
#          ('has', 'up'): Counter({'opened': 1.0}),
#          ('opened', 'a'): Counter({'up': 1.0}),
#          ('up', 'differential'): Counter({'a': 1.0}),
#          ('differential', 'European'): Counter({'with': 1.0}),
#          ('with', 'rates'): Counter({'European': 1.0}),
#          ('European', '.'): Counter({'rates': 1.0}),
#          ('rates', 'The'): Counter({'.': 1.0}),
#          ('.', 'half-point'): Counter({'The': 1.0}),
#          ('The', 'window'): Counter({'half-point': 1.0}),
#          ('half-point', ','): Counter({'window': 1.0}),
#          ('window', 'some'): Counter({',': 1.0}),
#          (',', 'believe'): Counter({'some': 1.0}),
#          ('believe', 'could'): Counter({',': 1.0}),
#          (',', 'be'): Counter({'could': 1.0}),
#          ('could', 'enough'): Counter({'be': 1.0}),
#          ('be', 'to'): Counter({'enough': 1.0}),
#          ('enough', 'keep'): Counter({'to': 1.0}),
#          ('to', 'US'): Counter({'keep': 1.0}),
#          ('keep', 'assets'): Counter({'US': 1.0}),
#          ('US', 'looking'): Counter({'assets': 1.0}),
#          ('assets', 'more'): Counter({'looking': 1.0}),
#          ('looking', 'attractive'): Counter({'more': 1.0}),
#          ('more', ','): Counter({'attractive': 1.0}),
#          ('attractive', 'and'): Counter({',': 1.0}),
#          (',', 'could'): Counter({'and': 1.0}),
#          ('and', 'help'): Counter({'could': 1.0}),
#          ('could', 'prop'): Counter({'help': 1.0}),
#          ('help', 'up'): Counter({'prop': 1.0}),
#          ('prop', 'the'): Counter({'up': 1.0}),
#          ('up', 'dollar'): Counter({'the': 1.0}),
#          ('dollar', 'The'): Counter({'.': 1.0}),
#          ('.', 'recent'): Counter({'The': 1.0}),
#          ('The', 'falls'): Counter({'recent': 1.0}),
#          ('falls', 'partly'): Counter({'have': 1.0}),
#          ('have', 'been'): Counter({'partly': 1.0}),
#          ('partly', 'the'): Counter({'been': 1.0}),
#          ('been', 'result'): Counter({'the': 1.0}),
#          ('result', 'big'): Counter({'of': 1.0}),
#          ('of', 'budget'): Counter({'big': 1.0}),
#          ('big', 'deficits'): Counter({'budget': 1.0}),
#          ('budget', ','): Counter({'deficits': 1.0}),
#          ('deficits', 'as'): Counter({',': 1.0}),
#          (',', 'well'): Counter({'as': 1.0}),
#          ('as', 'as'): Counter({'well': 1.0}),
#          ('well', 'the'): Counter({'as': 1.0}),
#          ('as', 'US'): Counter({'the': 1.0}),
#          ('US', 'yawning'): Counter({"'s": 1.0}),
#          ("'s", 'current'): Counter({'yawning': 1.0}),
#          ('yawning', 'account'): Counter({'current': 1.0}),
#          ('current', 'gap'): Counter({'account': 1.0}),
#          ('account', ','): Counter({'gap': 1.0}),
#          ('gap', 'both'): Counter({',': 1.0}),
#          ('both', 'which'): Counter({'of': 1.0}),
#          ('of', 'need'): Counter({'which': 1.0}),
#          ('which', 'to'): Counter({'need': 1.0}),
#          ('need', 'be'): Counter({'to': 1.0}),
#          ('to', 'funded'): Counter({'be': 1.0}),
#          ('be', 'by'): Counter({'funded': 1.0}),
#          ('funded', 'the'): Counter({'by': 1.0}),
#          ('by', 'buying'): Counter({'the': 1.0}),
#          ('buying', 'US'): Counter({'of': 1.0}),
#          ('of', 'bonds'): Counter({'US': 1.0}),
#          ('US', 'and'): Counter({'bonds': 1.0}),
#          ('bonds', 'assets'): Counter({'and': 1.0}),
#          ('and', 'by'): Counter({'assets': 1.0}),
#          ('assets', 'foreign'): Counter({'by': 1.0}),
#          ('by', 'firms'): Counter({'foreign': 1.0}),
#          ('foreign', 'and'): Counter({'firms': 1.0}),
#          ('firms', 'governments'): Counter({'and': 1.0}),
#          ('governments', 'The'): Counter({'.': 1.0}),
#          ('.', 'White'): Counter({'The': 1.0}),
#          ('The', 'House'): Counter({'White': 1.0}),
#          ('White', 'will'): Counter({'House': 1.0}),
#          ('House', 'announce'): Counter({'will': 1.0}),
#          ('will', 'its'): Counter({'announce': 1.0}),
#          ('announce', 'budget'): Counter({'its': 1.0}),
#          ('its', 'on'): Counter({'budget': 1.0}),
#          ('budget', 'Monday'): Counter({'on': 1.0}),
#          ('on', ','): Counter({'Monday': 1.0}),
#          ('Monday', 'and'): Counter({',': 1.0}),
#          (',', 'many'): Counter({'and': 1.0}),
#          ('and', 'commentators'): Counter({'many': 1.0}),
#          ('many', 'believe'): Counter({'commentators': 1.0}),
#          ('commentators', 'the'): Counter({'believe': 1.0}),
#          ('believe', 'deficit'): Counter({'the': 1.0}),
#          ('the', 'will'): Counter({'deficit': 1.0}),
#          ('deficit', 'remain'): Counter({'will': 1.0}),
#          ('will', 'at'): Counter({'remain': 1.0}),
#          ('remain', 'close'): Counter({'at': 1.0}),
#          ('at', 'to'): Counter({'close': 1.0}),
#          ('close', 'half'): Counter({'to': 1.0}),
#          ('to', 'a'): Counter({'half': 1.0}),
#          ('half', 'trillion'): Counter({'a': 1.0}),
#          ('a', 'dollars'): Counter({'trillion': 1.0}),
#          ('trillion', '.'): Counter({'dollars': 1.0}),
#          ('Yukos', 'buyer'): Counter({'unit': 1.0}),
#          ('unit', 'faces'): Counter({'buyer': 1.0}),
#          ('buyer', 'loan'): Counter({'faces': 1.0}),
#          ('faces', 'claim'): Counter({'loan': 1.0}),
#          ('The', 'of'): Counter({'owners': 1.0}),
#          ('owners', 'embattled'): Counter({'of': 1.0}),
#          ('of', 'Russian'): Counter({'embattled': 1.0}),
#          ('embattled', 'oil'): Counter({'Russian': 1.0}),
#          ('Russian', 'giant'): Counter({'oil': 1.0}),
#          ('oil', 'Yukos'): Counter({'giant': 1.0}),
#          ('giant', 'are'): Counter({'Yukos': 1.0}),
#          ('Yukos', 'to'): Counter({'are': 1.0}),
#          ('are', 'ask'): Counter({'to': 1.0}),
#          ('ask', 'buyer'): Counter({'the': 1.0}),
#          ('buyer', 'its'): Counter({'of': 1.0}),
#          ('of', 'former'): Counter({'its': 1.0}),
#          ('its', 'production'): Counter({'former': 1.0}),
#          ('former', 'unit'): Counter({'production': 1.0}),
#          ('production', 'to'): Counter({'unit': 1.0}),
#          ('unit', 'pay'): Counter({'to': 1.0}),
#          ('to', 'back'): Counter({'pay': 1.0}),
#          ('pay', 'a'): Counter({'back': 1.0}),
#          ('back', '$'): Counter({'a': 1.0}),
#          ('a', '900m'): Counter({'$': 1.0}),
#          ('900m', '£479m'): Counter({'(': 1.0}),
#          ('£479m', 'loan'): Counter({')': 1.0}),
#          (')', '.'): Counter({'loan': 1.0}),
#          ('State-owned', 'bought'): Counter({'Rosneft': 1.0}),
#          ('Rosneft', 'the'): Counter({'bought': 1.0}),
#          ('bought', 'Yugansk'): Counter({'the': 1.0}),
#          ('the', 'unit'): Counter({'Yugansk': 1.0}),
#          ('Yugansk', 'for'): Counter({'unit': 1.0}),
#          ('unit', '$'): Counter({'for': 1.0}),
#          ('for', '9.3bn'): Counter({'$': 1.0}),
#          ('$', 'in'): Counter({'9.3bn': 1.0}),
#          ('9.3bn', 'a'): Counter({'in': 1.0}),
#          ('in', 'sale'): Counter({'a': 1.0}),
#          ('a', 'forced'): Counter({'sale': 1.0}),
#          ('sale', 'by'): Counter({'forced': 1.0}),
#          ('forced', 'Russia'): Counter({'by': 1.0}),
#          ('by', 'to'): Counter({'Russia': 1.0}),
#          ('Russia', 'part'): Counter({'to': 1.0}),
#          ('to', 'settle'): Counter({'part': 1.0}),
#          ('part', 'a'): Counter({'settle': 1.0}),
#          ('settle', '$'): Counter({'a': 1.0}),
#          ('a', '27.5bn'): Counter({'$': 1.0}),
#          ('$', 'tax'): Counter({'27.5bn': 1.0}),
#          ('27.5bn', 'claim'): Counter({'tax': 1.0}),
#          ('tax', 'against'): Counter({'claim': 1.0}),
#          ('claim', 'Yukos'): Counter({'against': 1.0}),
#          ('against', '.'): Counter({'Yukos': 1.0}),
#          ('Yukos', 'Yukos'): Counter({'.': 1.0}),
#          ('.', "'"): Counter({'Yukos': 1.0}),
#          ('Yukos', 'owner'): Counter({"'": 1.0}),
#          ("'", 'Menatep'): Counter({'owner': 1.0}),
#          ('owner', 'Group'): Counter({'Menatep': 1.0}),
#          ('Menatep', 'says'): Counter({'Group': 1.0}),
#          ('Group', 'it'): Counter({'says': 1.0}),
#          ('says', 'will'): Counter({'it': 1.0}),
#          ('it', 'ask'): Counter({'will': 1.0}),
#          ('will', 'Rosneft'): Counter({'ask': 1.0}),
#          ('ask', 'to'): Counter({'Rosneft': 1.0}),
#          ('Rosneft', 'repay'): Counter({'to': 1.0}),
#          ('repay', 'loan'): Counter({'a': 1.0}),
#          ('loan', 'Yugansk'): Counter({'that': 1.0}),
#          ('that', 'had'): Counter({'Yugansk': 1.0}),
#          ('Yugansk', 'secured'): Counter({'had': 1.0}),
#          ('had', 'on'): Counter({'secured': 1.0}),
#          ('secured', 'its'): Counter({'on': 1.0}),
#          ('on', 'assets'): Counter({'its': 1.0}),
#          ('its', '.'): Counter({'assets': 1.0}),
#          ('assets', 'Rosneft'): Counter({'.': 1.0}),
#          ('.', 'already'): Counter({'Rosneft': 1.0}),
#          ('Rosneft', 'faces'): Counter({'already': 1.0}),
#          ('already', 'a'): Counter({'faces': 1.0}),
#          ('faces', 'similar'): Counter({'a': 1.0}),
#          ('a', '$'): Counter({'similar': 1.0}),
#          ('similar', '540m'): Counter({'$': 1.0}),
#          ('$', 'repayment'): Counter({'540m': 1.0}),
#          ('540m', 'demand'): Counter({'repayment': 1.0}),
#          ('repayment', 'from'): Counter({'demand': 1.0}),
#          ('demand', 'foreign'): Counter({'from': 1.0}),
#          ('from', 'banks'): Counter({'foreign': 1.0}),
#          ('foreign', '.'): Counter({'banks': 1.0}),
#          ('banks', 'Legal'): Counter({'.': 1.0}),
#          ('.', 'experts'): Counter({'Legal': 1.0}),
#          ('Legal', 'said'): Counter({'experts': 1.0}),
#          ('experts', 'Rosneft'): Counter({'said': 1.0}),
#          ('Rosneft', 'purchase'): Counter({"'s": 1.0}),
#          ('purchase', 'Yugansk'): Counter({'of': 1.0}),
#          ('of', 'would'): Counter({'Yugansk': 1.0}),
#          ('Yugansk', 'include'): Counter({'would': 1.0}),
#          ('would', 'such'): Counter({'include': 1.0}),
#          ('include', 'obligations'): Counter({'such': 1.0}),
#          ('such', '.'): Counter({'obligations': 1.0}),
#          ('obligations', '``'): Counter({'.': 1.0}),
#          ('.', 'The'): Counter({'``': 1.0}),
#          ('``', 'pledged'): Counter({'The': 1.0}),
#          ('The', 'assets'): Counter({'pledged': 1.0}),
#          ('pledged', 'are'): Counter({'assets': 1.0}),
#          ('assets', 'with'): Counter({'are': 1.0}),
#          ('are', 'Rosneft'): Counter({'with': 1.0}),
#          ('with', ','): Counter({'Rosneft': 1.0}),
#          ('Rosneft', 'so'): Counter({',': 1.0}),
#          ('so', 'will'): Counter({'it': 1.0}),
#          ('it', 'have'): Counter({'will': 1.0}),
#          ('have', 'pay'): Counter({'to': 1.0}),
#          ('to', 'real'): Counter({'pay': 1.0}),
#          ('pay', 'money'): Counter({'real': 1.0}),
#          ('real', 'to'): Counter({'money': 1.0}),
#          ('money', 'the'): Counter({'to': 1.0}),
#          ('to', 'creditors'): Counter({'the': 1.0}),
#          ('the', 'to'): Counter({'creditors': 1.0}),
#          ('creditors', 'avoid'): Counter({'to': 1.0}),
#          ('to', 'seizure'): Counter({'avoid': 1.0}),
#          ('avoid', 'of'): Counter({'seizure': 1.0}),
#          ('seizure', 'Yugansk'): Counter({'of': 1.0}),
#          ('of', 'assets'): Counter({'Yugansk': 1.0}),
#          ('Yugansk', ','): Counter({'assets': 1.0}),
#          ('assets', "''"): Counter({',': 1.0}),
#          ("''", 'Moscow-based'): Counter({'said': 1.0}),
#          ('Moscow-based', 'lawyer'): Counter({'US': 1.0}),
#          ('US', 'Jamie'): Counter({'lawyer': 1.0}),
#          ('lawyer', 'Firestone'): Counter({'Jamie': 1.0}),
#          ('Jamie', ','): Counter({'Firestone': 1.0}),
#          ('Firestone', 'who'): Counter({',': 1.0}),
#          ('who', 'not'): Counter({'is': 1.0}),
#          ('is', 'connected'): Counter({'not': 1.0}),
#          ('not', 'to'): Counter({'connected': 1.0}),
#          ('connected', 'the'): Counter({'to': 1.0}),
#          ('to', 'case'): Counter({'the': 1.0}),
#          ('case', 'Menatep'): Counter({'.': 1.0}),
#          ('.', 'Group'): Counter({'Menatep': 1.0}),
#          ('Menatep', "'s"): Counter({'Group': 1.0}),
#          ('Group', 'managing'): Counter({"'s": 1.0}),
#          ("'s", 'director'): Counter({'managing': 1.0}),
#          ('managing', 'Tim'): Counter({'director': 1.0}),
#          ('director', 'Osborne'): Counter({'Tim': 1.0}),
#          ('Tim', 'told'): Counter({'Osborne': 1.0}),
#          ('Osborne', 'the'): Counter({'told': 1.0}),
#          ('told', 'Reuters'): Counter({'the': 1.0}),
#          ('the', 'news'): Counter({'Reuters': 1.0}),
#          ('Reuters', 'agency'): Counter({'news': 1.0}),
#          ('news', ':'): Counter({'agency': 1.0}),
#          ('agency', '``'): Counter({':': 1.0}),
#          (':', 'If'): Counter({'``': 1.0}),
#          ('``', 'they'): Counter({'If': 1.0}),
#          ('If', 'default'): Counter({'they': 1.0}),
#          ('they', ','): Counter({'default': 1.0}),
#          ('default', 'we'): Counter({',': 1.0}),
#          (',', 'will'): Counter({'we': 1.0}),
#          ('we', 'fight'): Counter({'will': 1.0}),
#          ('will', 'them'): Counter({'fight': 1.0}),
#          ('fight', 'where'): Counter({'them': 1.0}),
#          ('them', 'the'): Counter({'where': 1.0}),
#          ('where', 'rule'): Counter({'the': 1.0}),
#          ('rule', 'law'): Counter({'of': 1.0}),
#          ('of', 'exists'): Counter({'law': 1.0}),
#          ('law', 'under'): Counter({'exists': 1.0}),
#          ('exists', 'the'): Counter({'under': 1.0}),
#          ...})

# %%
texts.iloc[0].split("\n")
# Out:
# ['Ad sales boost Time Warner profit',
#  '',
#  'Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (£600m) for the three months to December, from $639m year-earlier.',
#  '',
#  'The firm, which is now one of the biggest investors in Google, benefited from sales of high-speed internet connections and higher advert sales. TimeWarner said fourth quarter sales rose 2% to $11.1bn from $10.9bn. Its profits were buoyed by one-off gains which offset a profit dip at Warner Bros, and less users for AOL.',
#  '',
#  "Time Warner said on Friday that it now owns 8% of search-engine Google. But its own internet business, AOL, had has mixed fortunes. It lost 464,000 subscribers in the fourth quarter profits were lower than in the preceding three quarters. However, the company said AOL's underlying profit before exceptional items rose 8% on the back of stronger internet advertising revenues. It hopes to increase subscribers by offering the online service free to TimeWarner internet customers and will try to sign up AOL's existing customers for high-speed broadband. TimeWarner also has to restate 2000 and 2003 results following a probe by the US Securities Exchange Commission (SEC), which is close to concluding.",
#  '',
#  'Time Warner\'s fourth quarter profits were slightly better than analysts\' expectations. But its film division saw profits slump 27% to $284m, helped by box-office flops Alexander and Catwoman, a sharp contrast to year-earlier, when the third and final film in the Lord of the Rings trilogy boosted results. For the full-year, TimeWarner posted a profit of $3.36bn, up 27% from its 2003 performance, while revenues grew 6.4% to $42.09bn. "Our financial performance was strong, meeting or exceeding all of our full-year objectives and greatly enhancing our flexibility," chairman and chief executive Richard Parsons said. For 2005, TimeWarner is projecting operating earnings growth of around 5%, and also expects higher revenue and wider profit margins.',
#  '',
#  "TimeWarner is to restate its accounts as part of efforts to resolve an inquiry into AOL by US market regulators. It has already offered to pay $300m to settle charges, in a deal that is under review by the SEC. The company said it was unable to estimate the amount it needed to set aside for legal reserves, which it previously set at $500m. It intends to adjust the way it accounts for a deal with German music publisher Bertelsmann's purchase of a stake in AOL Europe, which it had reported as advertising revenue. It will now book the sale of its stake in AOL Europe as a loss on the value of that stake."]

# %%
def spin_document(doc):
    lines = doc.split("\n")
    output = []
    for line in lines:
        if line:
            new_line = spin_line(line)
        else:
            new_line = line
        output.append(new_line)
    return "\n".join(output)

# %%
detokenizer = TreebankWordDetokenizer()

# %%
texts.iloc[0].split("\n")[2]
# Out:
# 'Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (£600m) for the three months to December, from $639m year-earlier.'

# %%
detokenizer.detokenize(word_tokenize(texts.iloc[0].split("\n")[2]))
# Out:
# 'Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (£600m) for the three months to December, from $639m year-earlier.'

# %%
def sample_word(d):
    p0 = np.random.random()
    cumulative =0
    for k,v in d.items():
        cumulative += v
        if p0 < cumulative:
            return t
    assert(False)

# %%
def spin_line(line):
    tokens = word_tokenize(line)
    i = 0
    output = [tokens[0]]
    while i<len(tokens)-2:
        t_0 = tokens[i]
        t_1 = tokens[i+1]
        t_2 = tokens[i+2]
        key = (t_0,t_2)
        p_dist = probs[key]
        if len(p_dist)>1 and np.random.random() <0.3:
            middle = sample_word(p_dist)
            output.append(t_1)
            output.append("<" + middle + ">")
            output.append(t_2)

            i+=2
        else:
            output.append(t_1)
            i += 1
    if i == len(tokens)-2:
        output.append(tokens[-1])
    return detokenizer.detokenize(output)

# %%
np.random.seed(1234)

# %%
i = np.random.choice(texts.shape[0])
doc = texts.iloc[i]
new_doc = spin_document(doc)

# %%
new_doc
# Out:
# "MG Rover China tie-up 'delayed'\n\nMG Rover's proposed tie-up with China's top carmaker has been delayed due to concerns by Chinese regulators, according to the Financial Times.\n\nThe paper said Chinese officials had been irritated by Rover's disclosure of its talks with Shanghai Automotive Industry Corp in October . The proposed deal was seen as crucial to safeguarding the future of Rover's Longbridge plant in the West Midlands . However, there are growing fears that the deal could result in job losses . The Observer reported on Sunday that nearly half the workforce at Longbridge could be under threat if the deal goes ahead.\n\nShanghai Automotive's proposed £1bn investment in Rover is awaiting approval by its owner, the Shanghai city government and by the National Development and Reform Commission, which oversees foreign investment by Chinese firms . According to the FT, the regulator has been annoyed by Rover's decision to talk publicly about the deal and the intense speculation which has ensued about what it will mean for Rover's future . As a result, hopes that approval of the deal may be fast-tracked have disappeared, the paper said . There has been continued speculation about the viability of Rover's Longbridge plant because of falling sales and unfashionable models.\n\nAccording to the Observer, 3,000 jobs - out of a total workforce of 6,500 - could be lost if the deal goes ahead . The paper said that Chinese officials believe cutbacks will be required to keep the MG Rover's costs in line with revenues . It also said that the production of new models through the joint venture would take at least eighteen months . Neither Rover nor Shanghai Automotive commented on the reports."
